# %%
import numpy as np

# %%
concentracao_e = 10.0
concentracao_d = 75.0

# %%
n = 40
inc = (75 - 10) / n
np.arange(10, 75, inc)
# Out:
# array([10.   , 11.625, 13.25 , 14.875, 16.5  , 18.125, 19.75 , 21.375,
#        23.   , 24.625, 26.25 , 27.875, 29.5  , 31.125, 32.75 , 34.375,
#        36.   , 37.625, 39.25 , 40.875, 42.5  , 44.125, 45.75 , 47.375,
#        49.   , 50.625, 52.25 , 53.875, 55.5  , 57.125, 58.75 , 60.375,
#        62.   , 63.625, 65.25 , 66.875, 68.5  , 70.125, 71.75 , 73.375])
